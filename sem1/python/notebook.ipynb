# %% [markdown]
# <a href="https://colab.research.google.com/github/tanish19078/python-foundation/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -o brain_tumor_code.zip
# !unzip -q -o dataset.zip
# !pip install -r requirements_tuning.txt

# Run the ALL-IN-ONE script (Training + Tuning + Benchmarks)
# !python run_all.py
# Out:
# Archive:  brain_tumor_code.zip
#  extracting: train.py
#  extracting: tune_model.py
#  extracting: run_all.py
#  extracting: requirements_tuning.txt
#  extracting: notebook.ipynb
#  extracting: setup_data.py
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 13.6 MB/s eta 0:00:00
# ...
# [I 2025-12-13 07:19:35,935] A new study created in RDB with name: brain_tumor_study
# Starting Optuna optimization...
# Trial Params: {'model_name': 'mobilenetv3_large_100', 'lr': 0.0004717746833860702, 'bs': 16, 'optimizer': 'adam', 'p_aug': 0.6103921405471903}
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /content/run_all.py:86: UserWarning: Argument(s) 'min_holes, max_holes, min_height, max_height, min_width, max_width' are not valid for transform CoarseDropout
# ...
