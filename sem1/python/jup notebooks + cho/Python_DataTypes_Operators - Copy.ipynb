# %% [markdown]
# #  Python Basics: Data Types, Type Conversion & Operators
# **Objective:** This notebook demonstrates various data types in Python, type conversions, mixed-type expressions, and all categories of operators with examples.

# %% [markdown]
# 🔹 What is a Variable?
#
# A variable is a name that refers to a value stored in memory. It helps store and manage data in a program.

# %% [markdown]
# | Data Type | Description                            | Example                        |
# | --------- | -------------------------------------- | ------------------------------ |
# | `str`     | String - text data                     | `"Hello"`                      |
# | `int`     | Integer - whole numbers                | `42`                           |
# | `float`   | Floating-point - decimal numbers       | `3.14`                         |
# | `bool`    | Boolean - `True` or `False`            | `True`                         |
# | `list`    | Ordered, changeable, allows duplicates | `[1, 2, 3]`                    |
# | `tuple`   | Ordered, unchangeable (immutable)      | `(1, 2, 3)`                    |
# | `set`     | Unordered, no duplicates               | `{1, 2, 3}`                    |
# | `dict`    | Key-value pairs                        | `{"name": "Alice", "age": 21}` |

# %% [markdown]
# ##  Define Variables of Different Data Types

# %%
# String
name = "Python"
print(name, type(name))

# Integer
age = 21
print(age, type(age))

# Float
price = 99.99
print(price, type(price))

# Boolean
is_active = True
print(is_active, type(is_active))

# List
fruits = ["apple", "banana", "mango"]
print(fruits, type(fruits))

# Tuple
coordinates = (10.5, 20.3)
print(coordinates, type(coordinates))

# Set
colors = {"red", "green", "blue"}
print(colors, type(colors))

# Dictionary
student = {"name": "Alice", "marks": 85}
print(student, type(student))

# %% [markdown]
# ✅ 2. Type Conversion
# 🔹 What is Type Conversion?
#
# Changing one data type to another (e.g., int → float).
#
# 🔹 Types of Conversion:
#
# int() → Converts to integer
#
# float() → Converts to float
#
# str() → Converts to string
#
# 🔸 Examples:
# x = 10
# print(float(x))  # 10.0
#
# y = "25"
# print(int(y))    # 25
#
# z = 3.5
# print(str(z))    # "3.5"
#
#
# ⚠️ Make sure the string is numeric before converting it to int or float.

# %% [markdown]
# ## 🔁 Type Conversions (int, float, str)

# %%
# Integer to float
x = 10
print(float(x))

# Float to integer
y = 25.6
print(int(y))

# Integer to string
z = 100
print(str(z))

# String to integer (if numeric)
s = "200"
print(int(s))

# String to float
f = "45.78"
print(float(f))

# %% [markdown]
# ## 🎯 Mixed-Type Expressions

# %% [markdown]
# ✅ 3. Mixed-Type Expressions
#
# Mixing different types in a single expression:
#
# a = 10        # int
# b = 3.5       # float
# print(a + b)  # 13.5 (int + float → float)
#
#
# To mix string and int, use str():
#
# name = "Alice"
# age = 20
# print(name + " is " + str(age) + " years old.")

# %%
a = 10
b = 3.5
c = "5"

# Mixing int and float
result = a + b
print("a + b =", result)

# Mixing int and str (requires conversion)
print("a + c =", str(a) + c)  # String concatenation

# Adding converted string to int
print("a + int(c) =", a + int(c))

# %% [markdown]
# ## ➕ Arithmetic Operators

# %% [markdown]
# ✅ 4. Python Operators
# 🔹 Arithmetic Operators
# | Operator | Description         | Example (`a=10`, `b=3`) | Result |
# | -------- | ------------------- | ----------------------- | ------ |
# | `+`      | Addition            | `a + b`                 | `13`   |
# | `-`      | Subtraction         | `a - b`                 | `7`    |
# | `*`      | Multiplication      | `a * b`                 | `30`   |
# | `/`      | Division            | `a / b`                 | `3.33` |
# | `//`     | Floor Division      | `a // b`                | `3`    |
# | `%`      | Modulus (remainder) | `a % b`                 | `1`    |
# | `**`     | Exponentiation      | `a ** b`                | `1000` |

# %%
x = 10
y = 3
print("Addition:", x + y)
print("Subtraction:", x - y)
print("Multiplication:", x * y)
print("Division:", x / y)
print("Floor Division:", x // y)
print("Modulus:", x % y)
print("Exponent:", x ** y)

# %% [markdown]
# ## ⚖️ Comparison Operators

# %% [markdown]
# 🔹 Comparison Operators
#
# Used to compare values (returns True or False):
#
# | Operator | Meaning          | Example  |
# | -------- | ---------------- | -------- |
# | `==`     | Equal to         | `x == y` |
# | `!=`     | Not equal        | `x != y` |
# | `>`      | Greater than     | `x > y`  |
# | `<`      | Less than        | `x < y`  |
# | `>=`     | Greater or equal | `x >= y` |
# | `<=`     | Less or equal    | `x <= y` |

# %%
a = 5
b = 10
print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a < b:", a < b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)

# %% [markdown]
# ## 🔗 Logical Operators

# %% [markdown]
# 🔹 Logical Operators
#
# Used for combining conditions:
#
# | Operator | Meaning                      | Example            |
# | -------- | ---------------------------- | ------------------ |
# | `and`    | True if both are True        | `x > 5 and y < 10` |
# | `or`     | True if at least one is True | `x > 5 or y < 3`   |
# | `not`    | Reverses the condition       | `not(x > 5)`       |

# %%
x = True
y = False
print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)

# %% [markdown]
# ## 🖊️ Assignment Operators

# %% [markdown]
# 🔹 Assignment Operators
#
# Used to assign values to variables.
#
# | Operator | Meaning             | Example  |
# | -------- | ------------------- | -------- |
# | `=`      | Assign              | `x = 5`  |
# | `+=`     | Add and assign      | `x += 3` |
# | `-=`     | Subtract and assign | `x -= 2` |
# | `*=`     | Multiply and assign | `x *= 4` |
# | `/=`     | Divide and assign   | `x /= 2` |
# | `%=`     | Modulus and assign  | `x %= 2` |

# %%
a = 10
print("Initial a:", a)

a += 5
print("a += 5:", a)

a -= 3
print("a -= 3:", a)

a *= 2
print("a *= 2:", a)

a /= 4
print("a /= 4:", a)

a %= 3
print("a %= 3:", a)

# %%
Mini Project: "Simple Billing System for a Canteen"
🧠 Project Idea:

Create a menu-driven Python program that simulates a canteen billing system. 

The user can:

View a menu

Select items by entering quantity

See the final bill with tax and discounts.
